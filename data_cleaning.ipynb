# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74b0bdcc-9600-482d-ae91-91b744a981cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74b0bdcc-9600-482d-ae91-91b744a981cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45999f6a-8d0f-415b-b622-db8592fb5330" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45999f6a-8d0f-415b-b622-db8592fb5330">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-828ea30b-ec7d-4928-984c-bf97141d92a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-828ea30b-ec7d-4928-984c-bf97141d92a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02934440-9740-4a70-ae3c-cfae204abaf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02934440-9740-4a70-ae3c-cfae204abaf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68d14354-f7d0-475e-822a-de9ed142557e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68d14354-f7d0-475e-822a-de9ed142557e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
crime = pd.read_csv("/content/Crime.csv")
crime_person = pd.read_csv("/content/Crime Person.csv")
people = pd.read_csv("/content/People.csv")
crime_types = pd.read_csv("/content/Crime Type.csv")
crime_roles = pd.read_csv("/content/Crime Roles.csv")

# %%
crime.head()
# Out:
#    Crime ID  Crime Date   Latitude  Longitude  Crime Type ID  Resolved  \
# 0         1  01-09-2021  51.464348  -0.140717              1         0
# 1         2  02-08-2023  51.498368  -0.059213              9         0
# 2         3  10-04-2022  51.533161  -0.055350             12         0
# 3         4  21-09-2023  51.447567  -0.092034             11         1
# 4         5  02-04-2022  51.498684  -0.181090             12         1
#
#    People Involved    Crime DateTime
# 0                2  01.09.2021 02:00
# 1                2  02.08.2023 17:30
# 2                2  10.04.2022 22:35
# 3                5  21.09.2023 01:45
# 4                2  02.04.2022 20:40

# %%
crime_person.head()
# Out:
#    Crime ID  People Involved  Crime Role ID  Person ID
# 0         1                2              1        782
# 1         1                2              5       3930
# 2         2                2              1         25
# 3         2                2              5       1036
# 4         3                2              1       2751

# %%
people.head()
# Out:
#    Person ID             Name Date of Birth Gender   Ethnicity
# 0          1  Clarence Bowers    02-10-1988   Male  Ethnicity3
# 1          2     Timothy Pugh    21-12-1993   Male  Ethnicity3
# 2          3      Kaleb Nixon    28-09-1974   Male  Ethnicity5
# 3          4     Ronnie Curry    03-01-1973   Male  Ethnicity1
# 4          5       Drew Stein    24-11-1996   Male  Ethnicity1

# %%
crime_types.head()
# Out:
#    Crime Type ID                         Crime
# 0              1         Anti-Social Behaviour
# 1              2                 Bicycle Theft
# 2              3                      Burglary
# 3              4     Criminal Damage and Arson
# 4              5  Drugs and Illegal Substances

# %%
crime_roles.head()
# Out:
#    Crime Role ID        Role
# 0              1      Victim
# 1              2     Witness
# 2              3  Accomplice
# 3              4   Informant
# 4              5    Offender

# %%
crime.isnull().sum()
# Out:
# Crime ID           0
# Crime Date         0
# Latitude           0
# Longitude          0
# Crime Type ID      0
# Resolved           0
# People Involved    0
# Crime DateTime     0
# dtype: int64

# %%
crime_person.isnull().sum()
# Out:
# Crime ID           0
# People Involved    0
# Crime Role ID      0
# Person ID          0
# dtype: int64

# %%
people.isnull().sum()
# Out:
# Person ID        0
# Name             0
# Date of Birth    0
# Gender           0
# Ethnicity        0
# dtype: int64

# %%
crime_types.isnull().sum()
# Out:
# Crime Type ID    0
# Crime            0
# dtype: int64

# %%
crime_roles.isnull().sum()
# Out:
# Crime Role ID    0
# Role             0
# dtype: int64

# %%
crime.duplicated().sum()
# Out:
# np.int64(0)

# %%
crime_person.duplicated().sum()
# Out:
# np.int64(0)

# %%
crime_roles.duplicated().sum()
# Out:
# np.int64(0)

# %%
crime_types.duplicated().sum()
# Out:
# np.int64(0)

# %%
people.duplicated().sum()
# Out:
# np.int64(0)

# %%
crime["Crime Date"] = pd.to_datetime(crime["Crime Date"], errors="coerce")

crime["Latitude"] = pd.to_numeric(crime["Latitude"], errors="coerce")
crime["Longitude"] = pd.to_numeric(crime["Longitude"], errors="coerce")

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crime ID         2500 non-null   int64
#  1   Crime Date       1026 non-null   datetime64[ns]
#  2   Latitude         2500 non-null   float64
#  3   Longitude        2500 non-null   float64
#  4   Crime Type ID    2500 non-null   int64
#  5   Resolved         2500 non-null   int64
#  6   People Involved  2500 non-null   int64
#  7   Crime DateTime   2500 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 156.4+ KB

# %%
crime["Crime Date"]
# Out:
# 0      2021-01-09
# 1      2023-02-08
# 2      2022-10-04
# 3             NaT
# 4      2022-02-04
#           ...
# 2495   2021-04-10
# 2496   2022-12-01
# 2497   2022-12-10
# 2498   2023-10-09
# 2499   2021-03-10
# Name: Crime Date, Length: 2500, dtype: datetime64[ns]

# %%
crime["Crime Date"].head(10)
# Out:
# 0    01-09-2021
# 1    02-08-2023
# 2    10-04-2022
# 3    21-09-2023
# 4    02-04-2022
# 5    19-09-2022
# 6    15-09-2023
# 7    21-07-2023
# 8    11-09-2022
# 9    19-10-2023
# Name: Crime Date, dtype: object

# %%
crime["Crime Date"] = pd.to_datetime(crime["Crime Date"], format="%d-%m-%Y", errors="coerce")

# %%
crime["Crime Date"].head(10)
# Out:
# 0   2021-09-01
# 1   2023-08-02
# 2   2022-04-10
# 3   2023-09-21
# 4   2022-04-02
# 5   2022-09-19
# 6   2023-09-15
# 7   2023-07-21
# 8   2022-09-11
# 9   2023-10-19
# Name: Crime Date, dtype: datetime64[ns]

# %%
crime["Crime Date"].isnull().sum()
# Out:
# np.int64(0)

# %%
crime["Crime Date"]
# Out:
# 0      2021-09-01
# 1      2023-08-02
# 2      2022-04-10
# 3      2023-09-21
# 4      2022-04-02
#           ...
# 2495   2021-10-04
# 2496   2022-01-12
# 2497   2022-10-12
# 2498   2023-09-10
# 2499   2021-10-03
# Name: Crime Date, Length: 2500, dtype: datetime64[ns]
